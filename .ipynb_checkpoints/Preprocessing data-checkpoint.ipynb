# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import date

# %%
data = pd.read_csv('%s.csv'%str(date.today()))

# %%
data = data.drop(['Unnamed: 0', '#','1 Caseevery X ppl','1 Deathevery X ppl','1 Testevery X ppl','New Cases/1M pop','New Deaths/1M pop','Active Cases/1M pop'],axis=1)
Toltal = data.iloc[0]
data = data.drop(0, axis =0)
data = data.rename(columns={'Tests/\n1M pop\n':'Tests/1M pop'},inplace= False)
data = data.set_index(np.arange(len(data)), drop = True)

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases TotalDeaths NewDeaths  \
# 0                      USA  33,629,571    +3,474    598,583        +43
# 1                    India  24,320,668  +274,548    265,041     +2,691
# 2                   Brazil  15,436,827       NaN    430,596        NaN
# 3                   France   5,841,129       NaN    107,250        NaN
# 4                   Turkey   5,083,996       NaN     44,059        NaN
# ..                     ...         ...       ...         ...       ...
# 217  Saint Pierre Miquelon          25       NaN                   NaN
# 218        Solomon Islands          20       NaN                   NaN
# 219       Marshall Islands           4       NaN                   NaN
# 220           Saint Helena           2       NaN                   NaN
# 221             Micronesia           1       NaN                   NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# 0       26,668,149         +950   6,362,839            8,611          101,087
# 1       20,351,524     +278,157   3,704,103            8,944           17,475
# 2       13,979,329          NaN   1,026,902            8,318           72,180
# 3        4,999,079          NaN     734,800            4,442           89,316
# 4        4,856,763          NaN     183,174            2,765           59,726
# ..             ...          ...         ...              ...              ...
# 217             25          NaN           0              NaN            4,334
# 218             20          NaN           0              NaN               29
# 219              4          NaN           0              NaN               67
# 220              2          NaN           0              NaN              328
# 221              1          NaN           0              NaN                9
#
#     Deaths/1M pop   TotalTests Tests/1M pop      Population          Continent
# 0           1,799  462,833,291    1,391,226    332,680,263       North America
# 1             190  311,324,100      223,698  1,391,716,282                Asia
# 2           2,013   46,970,130      219,625    213,864,852       South America
# 3           1,640   80,214,807    1,226,555     65,398,484              Europe
# 4             518   50,259,943      590,444     85,122,228                Asia
# ..            ...          ...          ...             ...                ...
# 217           NaN        5,318      921,824          5,769       North America
# 218           NaN        4,500        6,416        701,349   Australia/Oceania
# 219           NaN          NaN          NaN         59,535   Australia/Oceania
# 220           NaN          NaN          NaN          6,093              Africa
# 221           NaN          NaN          NaN        116,064   Australia/Oceania
#
# [222 rows x 15 columns]

# %% [markdown]
# - Kiểm tra duplicate

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    object
#  2   NewCases          82 non-null     object
#  3   TotalDeaths       222 non-null    object
#  4   NewDeaths         64 non-null     object
#  5   TotalRecovered    222 non-null    object
#  6   NewRecovered      76 non-null     object
#  7   ActiveCases       222 non-null    object
#  8   Serious,Critical  149 non-null    object
#  9   Tot Cases/1M pop  220 non-null    object
#  10  Deaths/1M pop     206 non-null    object
#  11  TotalTests        210 non-null    object
#  12  Tests/1M pop      210 non-null    object
#  13  Population        222 non-null    object
#  14  Continent         220 non-null    object
# dtypes: object(15)
# memory usage: 27.8+ KB

# %% [markdown]
# - Các cột được chia ra thành hai hai kiểu dữ liệu đó là:
#     + cate_cols: bao gồm hai cột là : 'Country,Other','Continent'
#     + numberic_cols: bao gồm các cột còn lại.

# %%
cate_cols = ['Country,Other','Continent']
numberic_cols = data.columns.difference(cate_cols)

# %%
numberic_cols
# Out:
# Index(['ActiveCases', 'Deaths/1M pop', 'NewCases', 'NewDeaths', 'NewRecovered',
#        'Population', 'Serious,Critical', 'Tests/1M pop', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'TotalTests', 'Tot Cases/1M pop'],
#       dtype='object')

# %%
data[numberic_cols]
# Out:
#     ActiveCases Deaths/1M pop  NewCases NewDeaths NewRecovered  \
# 0     6,362,839         1,799    +3,474       +43         +950
# 1     3,704,103           190  +274,548    +2,691     +278,157
# 2     1,026,902         2,013       NaN       NaN          NaN
# 3       734,800         1,640       NaN       NaN          NaN
# 4       183,174           518       NaN       NaN          NaN
# ..          ...           ...       ...       ...          ...
# 217           0           NaN       NaN       NaN          NaN
# 218           0           NaN       NaN       NaN          NaN
# 219           0           NaN       NaN       NaN          NaN
# 220           0           NaN       NaN       NaN          NaN
# 221           0           NaN       NaN       NaN          NaN
#
#          Population Serious,Critical Tests/1M pop  TotalCases TotalDeaths  \
# 0      332,680,263             8,611    1,391,226  33,629,571    598,583
# 1    1,391,716,282             8,944      223,698  24,320,668    265,041
# 2      213,864,852             8,318      219,625  15,436,827    430,596
# 3       65,398,484             4,442    1,226,555   5,841,129    107,250
# 4       85,122,228             2,765      590,444   5,083,996     44,059
# ..              ...              ...          ...         ...         ...
# 217          5,769               NaN      921,824          25
# 218        701,349               NaN        6,416          20
# 219         59,535               NaN          NaN           4
# 220          6,093               NaN          NaN           2
# 221        116,064               NaN          NaN           1
#
#     TotalRecovered   TotalTests Tot Cases/1M pop
# 0       26,668,149  462,833,291          101,087
# 1       20,351,524  311,324,100           17,475
# 2       13,979,329   46,970,130           72,180
# 3        4,999,079   80,214,807           89,316
# 4        4,856,763   50,259,943           59,726
# ..             ...          ...              ...
# 217             25        5,318            4,334
# 218             20        4,500               29
# 219              4          NaN               67
# 220              2          NaN              328
# 221              1          NaN                9
#
# [222 rows x 13 columns]

# %% [markdown]
# - Xử lí các cột dữ liệu numberic:
#     + Xóa dấu '+' đứng trước mỗi giá trị.
#     + Điền các giá trị thiếu bằng '0'
#     + Chuyển đổi kiểu dữ liệu từ object sang kiểu int64

# %%
data[numberic_cols] = data[numberic_cols].apply\
(lambda x: x.str.replace(re.compile(r'[+.,]'), '').replace(' ',np.nan)).fillna('0').astype('int64')

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33629571      3474       598583         43
# 1                    India    24320668    274548       265041       2691
# 2                   Brazil    15436827         0       430596          0
# 3                   France     5841129         0       107250          0
# 4                   Turkey     5083996         0        44059          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26668149           950      6362839              8611
# 1          20351524        278157      3704103              8944
# 2          13979329             0      1026902              8318
# 3           4999079             0       734800              4442
# 4           4856763             0       183174              2765
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              101087           1799   462833291       1391226   332680263
# 1               17475            190   311324100        223698  1391716282
# 2               72180           2013    46970130        219625   213864852
# 3               89316           1640    80214807       1226555    65398484
# 4               59726            518    50259943        590444    85122228
# ..                ...            ...         ...           ...         ...
# 217              4334              0        5318        921824        5769
# 218                29              0        4500          6416      701349
# 219                67              0           0             0       59535
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116064
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]

# %%
data[cate_cols].isna().sum()
# Out:
# Country,Other    0
# Continent        2
# dtype: int64

# %%
data[data.Continent.isna()]
# Out:
#         Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 209  Diamond Princess         712         0           13          0
# 212        MS Zaandam           9         0            2          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 209             699             0            0                 0
# 212               7             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 209                 0              0           0             0           0
# 212                 0              0           0             0           0
#
#     Continent
# 209       NaN
# 212       NaN

# %% [markdown]
# - Sau khi tìm hiểu Diamond Princess và MS Zaandam là hai du thuyền bị nhiễm corona nên sẽ điền vào ở thuộc tính Continent là Ship

# %%
data[cate_cols] = data[cate_cols].fillna('Ship')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    int64
#  2   NewCases          222 non-null    int64
#  3   TotalDeaths       222 non-null    int64
#  4   NewDeaths         222 non-null    int64
#  5   TotalRecovered    222 non-null    int64
#  6   NewRecovered      222 non-null    int64
#  7   ActiveCases       222 non-null    int64
#  8   Serious,Critical  222 non-null    int64
#  9   Tot Cases/1M pop  222 non-null    int64
#  10  Deaths/1M pop     222 non-null    int64
#  11  TotalTests        222 non-null    int64
#  12  Tests/1M pop      222 non-null    int64
#  13  Population        222 non-null    int64
#  14  Continent         222 non-null    object
# dtypes: int64(13), object(2)
# memory usage: 27.8+ KB

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33629571      3474       598583         43
# 1                    India    24320668    274548       265041       2691
# 2                   Brazil    15436827         0       430596          0
# 3                   France     5841129         0       107250          0
# 4                   Turkey     5083996         0        44059          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26668149           950      6362839              8611
# 1          20351524        278157      3704103              8944
# 2          13979329             0      1026902              8318
# 3           4999079             0       734800              4442
# 4           4856763             0       183174              2765
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              101087           1799   462833291       1391226   332680263
# 1               17475            190   311324100        223698  1391716282
# 2               72180           2013    46970130        219625   213864852
# 3               89316           1640    80214807       1226555    65398484
# 4               59726            518    50259943        590444    85122228
# ..                ...            ...         ...           ...         ...
# 217              4334              0        5318        921824        5769
# 218                29              0        4500          6416      701349
# 219                67              0           0             0       59535
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116064
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    int64
#  2   NewCases          222 non-null    int64
#  3   TotalDeaths       222 non-null    int64
#  4   NewDeaths         222 non-null    int64
#  5   TotalRecovered    222 non-null    int64
#  6   NewRecovered      222 non-null    int64
#  7   ActiveCases       222 non-null    int64
#  8   Serious,Critical  222 non-null    int64
#  9   Tot Cases/1M pop  222 non-null    int64
#  10  Deaths/1M pop     222 non-null    int64
#  11  TotalTests        222 non-null    int64
#  12  Tests/1M pop      222 non-null    int64
#  13  Population        222 non-null    int64
#  14  Continent         222 non-null    object
# dtypes: int64(13), object(2)
# memory usage: 27.8+ KB

# %%
data.to_csv('%s_copy.csv'%str(date.today()))

# %%
pd.read_csv('%s_copy.csv'%str(date.today()), index_col=0)
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33629571      3474       598583         43
# 1                    India    24320668    274548       265041       2691
# 2                   Brazil    15436827         0       430596          0
# 3                   France     5841129         0       107250          0
# 4                   Turkey     5083996         0        44059          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26668149           950      6362839              8611
# 1          20351524        278157      3704103              8944
# 2          13979329             0      1026902              8318
# 3           4999079             0       734800              4442
# 4           4856763             0       183174              2765
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              101087           1799   462833291       1391226   332680263
# 1               17475            190   311324100        223698  1391716282
# 2               72180           2013    46970130        219625   213864852
# 3               89316           1640    80214807       1226555    65398484
# 4               59726            518    50259943        590444    85122228
# ..                ...            ...         ...           ...         ...
# 217              4334              0        5318        921824        5769
# 218                29              0        4500          6416      701349
# 219                67              0           0             0       59535
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116064
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]
