# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import date

# %%
data = pd.read_csv('%s.csv'%str(date.today()))

# %%
data = data.drop(['Unnamed: 0', '#','1 Caseevery X ppl','1 Deathevery X ppl','1 Testevery X ppl','New Cases/1M pop','New Deaths/1M pop','Active Cases/1M pop'],axis=1)
Toltal = data.iloc[0]
data = data.drop(0, axis =0)
data = data.rename(columns={'Tests/\n1M pop\n':'Tests/1M pop'},inplace= False)
data = data.set_index(np.arange(len(data)), drop = True)

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases TotalDeaths NewDeaths  \
# 0                      USA  33,554,277    +4,162    597,052       +106
# 1                    India  23,588,999  +248,573    256,940     +2,715
# 2                   Brazil  15,285,048       NaN    425,711        NaN
# 3                   France   5,800,170       NaN    106,935        NaN
# 4                   Turkey   5,059,433       NaN     43,589        NaN
# ..                     ...         ...       ...         ...       ...
# 217  Saint Pierre Miquelon          25       NaN                   NaN
# 218        Solomon Islands          20       NaN                   NaN
# 219       Marshall Islands           4       NaN                   NaN
# 220           Saint Helena           2       NaN                   NaN
# 221             Micronesia           1       NaN                   NaN
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical Tot Cases/1M pop  \
# 0       26,558,619         +481   6,398,606            8,775          100,864
# 1       19,611,259     +234,609   3,720,800            8,944           16,950
# 2       13,847,191          NaN   1,012,146            8,318           71,473
# 3        4,951,745          NaN     741,490            4,743           88,691
# 4        4,766,124          NaN     249,720            2,975           59,441
# ..             ...          ...         ...              ...              ...
# 217             25          NaN           0              NaN            4,333
# 218             20          NaN           0              NaN               29
# 219              4          NaN           0              NaN               67
# 220              2          NaN           0              NaN              328
# 221              1          NaN           0              NaN                9
#
#     Deaths/1M pop   TotalTests Tests/1M pop      Population          Continent
# 0           1,795  460,458,760    1,384,132    332,669,677       North America
# 1             185  307,583,991      221,022  1,391,642,201                Asia
# 2           1,991   46,834,128      218,998    213,856,608       South America
# 3           1,635   79,617,249    1,217,432     65,397,697              Europe
# 4             512   49,830,456      585,433     85,117,272                Asia
# ..            ...          ...          ...             ...                ...
# 217           NaN        5,318      921,664          5,770       North America
# 218           NaN        4,500        6,417        701,257   Australia/Oceania
# 219           NaN          NaN          NaN         59,533   Australia/Oceania
# 220           NaN          NaN          NaN          6,093              Africa
# 221           NaN          NaN          NaN        116,057   Australia/Oceania
#
# [222 rows x 15 columns]

# %% [markdown]
# - Kiểm tra duplicate

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    object
#  2   NewCases          88 non-null     object
#  3   TotalDeaths       222 non-null    object
#  4   NewDeaths         67 non-null     object
#  5   TotalRecovered    222 non-null    object
#  6   NewRecovered      85 non-null     object
#  7   ActiveCases       222 non-null    object
#  8   Serious,Critical  147 non-null    object
#  9   Tot Cases/1M pop  220 non-null    object
#  10  Deaths/1M pop     206 non-null    object
#  11  TotalTests        210 non-null    object
#  12  Tests/1M pop      210 non-null    object
#  13  Population        222 non-null    object
#  14  Continent         220 non-null    object
# dtypes: object(15)
# memory usage: 27.8+ KB

# %% [markdown]
# - Các cột được chia ra thành hai hai kiểu dữ liệu đó là:
#     + cate_cols: bao gồm hai cột là : 'Country,Other','Continent'
#     + numberic_cols: bao gồm các cột còn lại.

# %%
cate_cols = ['Country,Other','Continent']
numberic_cols = data.columns.difference(cate_cols)

# %%
numberic_cols
# Out:
# Index(['ActiveCases', 'Deaths/1M pop', 'NewCases', 'NewDeaths', 'NewRecovered',
#        'Population', 'Serious,Critical', 'Tests/1M pop', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'TotalTests', 'Tot Cases/1M pop'],
#       dtype='object')

# %%
data[numberic_cols]
# Out:
#     ActiveCases Deaths/1M pop  NewCases NewDeaths NewRecovered  \
# 0     6,398,606         1,795    +4,162      +106         +481
# 1     3,720,800           185  +248,573    +2,715     +234,609
# 2     1,012,146         1,991       NaN       NaN          NaN
# 3       741,490         1,635       NaN       NaN          NaN
# 4       249,720           512       NaN       NaN          NaN
# ..          ...           ...       ...       ...          ...
# 217           0           NaN       NaN       NaN          NaN
# 218           0           NaN       NaN       NaN          NaN
# 219           0           NaN       NaN       NaN          NaN
# 220           0           NaN       NaN       NaN          NaN
# 221           0           NaN       NaN       NaN          NaN
#
#          Population Serious,Critical Tests/1M pop  TotalCases TotalDeaths  \
# 0      332,669,677             8,775    1,384,132  33,554,277    597,052
# 1    1,391,642,201             8,944      221,022  23,588,999    256,940
# 2      213,856,608             8,318      218,998  15,285,048    425,711
# 3       65,397,697             4,743    1,217,432   5,800,170    106,935
# 4       85,117,272             2,975      585,433   5,059,433     43,589
# ..              ...              ...          ...         ...         ...
# 217          5,770               NaN      921,664          25
# 218        701,257               NaN        6,417          20
# 219         59,533               NaN          NaN           4
# 220          6,093               NaN          NaN           2
# 221        116,057               NaN          NaN           1
#
#     TotalRecovered   TotalTests Tot Cases/1M pop
# 0       26,558,619  460,458,760          100,864
# 1       19,611,259  307,583,991           16,950
# 2       13,847,191   46,834,128           71,473
# 3        4,951,745   79,617,249           88,691
# 4        4,766,124   49,830,456           59,441
# ..             ...          ...              ...
# 217             25        5,318            4,333
# 218             20        4,500               29
# 219              4          NaN               67
# 220              2          NaN              328
# 221              1          NaN                9
#
# [222 rows x 13 columns]

# %% [markdown]
# - Xử lí các cột dữ liệu numberic:
#     + Xóa dấu '+' đứng trước mỗi giá trị.
#     + Điền các giá trị thiếu bằng '0'
#     + Chuyển đổi kiểu dữ liệu từ object sang kiểu int64

# %%
data[numberic_cols] = data[numberic_cols].apply\
(lambda x: x.str.replace(re.compile(r'[+.,]'), '').replace(' ',np.nan)).fillna('0').astype('int64')

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33554277      4162       597052        106
# 1                    India    23588999    248573       256940       2715
# 2                   Brazil    15285048         0       425711          0
# 3                   France     5800170         0       106935          0
# 4                   Turkey     5059433         0        43589          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26558619           481      6398606              8775
# 1          19611259        234609      3720800              8944
# 2          13847191             0      1012146              8318
# 3           4951745             0       741490              4743
# 4           4766124             0       249720              2975
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              100864           1795   460458760       1384132   332669677
# 1               16950            185   307583991        221022  1391642201
# 2               71473           1991    46834128        218998   213856608
# 3               88691           1635    79617249       1217432    65397697
# 4               59441            512    49830456        585433    85117272
# ..                ...            ...         ...           ...         ...
# 217              4333              0        5318        921664        5770
# 218                29              0        4500          6417      701257
# 219                67              0           0             0       59533
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116057
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]

# %%
data[cate_cols].isna().sum()
# Out:
# Country,Other    0
# Continent        2
# dtype: int64

# %%
data[data.Continent.isna()]
# Out:
#         Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 208  Diamond Princess         712         0           13          0
# 211        MS Zaandam           9         0            2          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 208             699             0            0                 0
# 211               7             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 208                 0              0           0             0           0
# 211                 0              0           0             0           0
#
#     Continent
# 208       NaN
# 211       NaN

# %% [markdown]
# - Sau khi tìm hiểu Diamond Princess và MS Zaandam là hai du thuyền bị nhiễm corona nên sẽ điền vào ở thuộc tính Continent là Ship

# %%
data[cate_cols] = data[cate_cols].fillna('Ship')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    int64
#  2   NewCases          222 non-null    int64
#  3   TotalDeaths       222 non-null    int64
#  4   NewDeaths         222 non-null    int64
#  5   TotalRecovered    222 non-null    int64
#  6   NewRecovered      222 non-null    int64
#  7   ActiveCases       222 non-null    int64
#  8   Serious,Critical  222 non-null    int64
#  9   Tot Cases/1M pop  222 non-null    int64
#  10  Deaths/1M pop     222 non-null    int64
#  11  TotalTests        222 non-null    int64
#  12  Tests/1M pop      222 non-null    int64
#  13  Population        222 non-null    int64
#  14  Continent         222 non-null    object
# dtypes: int64(13), object(2)
# memory usage: 27.8+ KB

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33554277      4162       597052        106
# 1                    India    23588999    248573       256940       2715
# 2                   Brazil    15285048         0       425711          0
# 3                   France     5800170         0       106935          0
# 4                   Turkey     5059433         0        43589          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26558619           481      6398606              8775
# 1          19611259        234609      3720800              8944
# 2          13847191             0      1012146              8318
# 3           4951745             0       741490              4743
# 4           4766124             0       249720              2975
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              100864           1795   460458760       1384132   332669677
# 1               16950            185   307583991        221022  1391642201
# 2               71473           1991    46834128        218998   213856608
# 3               88691           1635    79617249       1217432    65397697
# 4               59441            512    49830456        585433    85117272
# ..                ...            ...         ...           ...         ...
# 217              4333              0        5318        921664        5770
# 218                29              0        4500          6417      701257
# 219                67              0           0             0       59533
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116057
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 221
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country,Other     222 non-null    object
#  1   TotalCases        222 non-null    int64
#  2   NewCases          222 non-null    int64
#  3   TotalDeaths       222 non-null    int64
#  4   NewDeaths         222 non-null    int64
#  5   TotalRecovered    222 non-null    int64
#  6   NewRecovered      222 non-null    int64
#  7   ActiveCases       222 non-null    int64
#  8   Serious,Critical  222 non-null    int64
#  9   Tot Cases/1M pop  222 non-null    int64
#  10  Deaths/1M pop     222 non-null    int64
#  11  TotalTests        222 non-null    int64
#  12  Tests/1M pop      222 non-null    int64
#  13  Population        222 non-null    int64
#  14  Continent         222 non-null    object
# dtypes: int64(13), object(2)
# memory usage: 27.8+ KB

# %%
data.to_csv('%s_copy.csv'%str(date.today()))

# %%
pd.read_csv('%s_copy.csv'%str(date.today()), index_col=0)
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    33554277      4162       597052        106
# 1                    India    23588999    248573       256940       2715
# 2                   Brazil    15285048         0       425711          0
# 3                   France     5800170         0       106935          0
# 4                   Turkey     5059433         0        43589          0
# ..                     ...         ...       ...          ...        ...
# 217  Saint Pierre Miquelon          25         0            0          0
# 218        Solomon Islands          20         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220           Saint Helena           2         0            0          0
# 221             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 0          26558619           481      6398606              8775
# 1          19611259        234609      3720800              8944
# 2          13847191             0      1012146              8318
# 3           4951745             0       741490              4743
# 4           4766124             0       249720              2975
# ..              ...           ...          ...               ...
# 217              25             0            0                 0
# 218              20             0            0                 0
# 219               4             0            0                 0
# 220               2             0            0                 0
# 221               1             0            0                 0
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop  Population  \
# 0              100864           1795   460458760       1384132   332669677
# 1               16950            185   307583991        221022  1391642201
# 2               71473           1991    46834128        218998   213856608
# 3               88691           1635    79617249       1217432    65397697
# 4               59441            512    49830456        585433    85117272
# ..                ...            ...         ...           ...         ...
# 217              4333              0        5318        921664        5770
# 218                29              0        4500          6417      701257
# 219                67              0           0             0       59533
# 220               328              0           0             0        6093
# 221                 9              0           0             0      116057
#
#              Continent
# 0        North America
# 1                 Asia
# 2        South America
# 3               Europe
# 4                 Asia
# ..                 ...
# 217      North America
# 218  Australia/Oceania
# 219  Australia/Oceania
# 220             Africa
# 221  Australia/Oceania
#
# [222 rows x 15 columns]
