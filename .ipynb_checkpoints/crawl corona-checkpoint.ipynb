# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
from urllib import parse
import numpy as np

# %%
url = 'https://www.worldometers.info/coronavirus/'

# %%
html_text = requests.get(url).text

# %%
#html_text

# %%
tree = BeautifulSoup(html_text, "html.parser")

# %%
#tree

# %%
cols = tree.find('thead').find_all('th')

# %%
len(cols)
# Out:
# 22

# %%
columns = []
for col in cols:
    columns.append(col.text)

# %%
lines1 = tree.find('tbody').find_all('tr',{'style':''})
lines2 = tree.find('tbody').find_all('tr',{'style':'background-color:#F0F0F0'})
lines3 = tree.find('tbody').find_all('tr',{'style':'background-color:#EAF7D5'})

# %%
lines = lines1 + lines2 + lines3

# %%
data = []

for line in lines:
    row = []
    for l in line.find_all('td'):
        row.append(l.text)
    data.append(row)

# %%
df = pd.DataFrame(np.array(data), columns=columns)

# %%
df
# Out:
#        #          Country,Other   TotalCases  NewCases TotalDeaths NewDeaths  \
# 0                         World  161,472,416  +395,655   3,351,188    +6,379
# 1      1                    USA   33,590,587    +4,451    597,864        +79
# 2      2                  India   23,943,878  +241,046    261,053     +2,702
# 3      3                 Brazil   15,361,686              428,256
# 4      4                 France    5,821,668              107,119
# ..   ...                    ...          ...       ...         ...       ...
# 218  212  Saint Pierre Miquelon           25
# 219  214        Solomon Islands           20
# 220  218       Marshall Islands            4
# 221  220           Saint Helena            2
# 222  221             Micronesia            1
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical  ...  \
# 0      140,292,568     +443,298  17,828,660          104,635  ...
# 1       26,621,706       +1,477   6,371,017            8,702  ...
# 2       19,983,310     +254,874   3,699,515            8,944  ...
# 3       13,924,217                1,009,213            8,318  ...
# 4        4,960,097                  754,452            4,583  ...
# ..             ...          ...         ...              ...  ...
# 218             25                        0                   ...
# 219             20                        0                   ...
# 220              4                        0                   ...
# 221              2                        0                   ...
# 222              1                        0                   ...
#
#       TotalTests Tests/\n1M pop\n      Population          Continent  \
# 0                                                                All
# 1    461,566,957        1,387,441    332,674,970       North America
# 2    309,448,585          222,356  1,391,679,242                Asia
# 3     46,970,130          219,630    213,860,730       South America
# 4     79,684,856        1,218,458     65,398,090              Europe
# ..           ...              ...             ...                ...
# 218        5,318          921,664          5,770       North America
# 219        4,500            6,417        701,303   Australia/Oceania
# 220                                       59,534   Australia/Oceania
# 221                                        6,093              Africa
# 222                                      116,060   Australia/Oceania
#
#     1 Caseevery X ppl 1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop  \
# 0                  \n
# 1                  10                556                 1               13
# 2                  58              5,331                 4              173
# 3                  14                499                 5
# 4                  11                611                 1
# ..                ...                ...               ...              ...
# 218               231                                    1
# 219            35,065                                  156
# 220            14,884
# 221             3,047
# 222           116,060
#
#     New Deaths/1M pop Active Cases/1M pop
# 0
# 1                 0.2              19,151
# 2                   2               2,658
# 3                                   4,719
# 4                                  11,536
# ..                ...                 ...
# 218
# 219
# 220
# 221
# 222
#
# [223 rows x 22 columns]

# %%
from datetime import date
today = date.today()
df.to_csv('%s.csv'% str(today))

# %%
today = date.today()
str(today)
# Out:
# '2021-05-13'
