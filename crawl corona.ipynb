# %%
import requests
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
from urllib import parse
import numpy as np

# %%
url = 'https://www.worldometers.info/coronavirus/'

# %%
html_text = requests.get(url).text

# %%
#html_text

# %%
tree = BeautifulSoup(html_text, "html.parser")

# %%
#tree

# %%
cols = tree.find('thead').find_all('th')

# %%
len(cols)
# Out:
# 22

# %%
columns = []
for col in cols:
    columns.append(col.text)

# %%
lines1 = tree.find('tbody').find_all('tr',{'style':''})
lines2 = tree.find('tbody').find_all('tr',{'style':'background-color:#F0F0F0'})
lines3 = tree.find('tbody').find_all('tr',{'style':'background-color:#EAF7D5'})

# %%
lines = lines1 + lines2 + lines3

# %%
data = []

for line in lines:
    row = []
    for l in line.find_all('td'):
        row.append(l.text)
    data.append(row)

# %%
df = pd.DataFrame(np.array(data), columns=columns)

# %%
df
# Out:
#        #          Country,Other   TotalCases  NewCases TotalDeaths NewDeaths  \
# 0                         World  160,720,960  +395,091   3,337,515    +6,596
# 1      1                    USA   33,554,277    +4,162    597,052       +106
# 2      2                  India   23,588,999  +248,573    256,940     +2,715
# 3      3                 Brazil   15,285,048              425,711
# 4      4                 France    5,800,170              106,935
# ..   ...                    ...          ...       ...         ...       ...
# 218  212  Saint Pierre Miquelon           25
# 219  214        Solomon Islands           20
# 220  218       Marshall Islands            4
# 221  220           Saint Helena            2
# 222  221             Micronesia            1
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical  ...  \
# 0      139,481,568     +445,431  17,901,877          105,804  ...
# 1       26,558,619         +481   6,398,606            8,775  ...
# 2       19,611,259     +234,609   3,720,800            8,944  ...
# 3       13,847,191                1,012,146            8,318  ...
# 4        4,951,745                  741,490            4,743  ...
# ..             ...          ...         ...              ...  ...
# 218             25                        0                   ...
# 219             20                        0                   ...
# 220              4                        0                   ...
# 221              2                        0                   ...
# 222              1                        0                   ...
#
#       TotalTests Tests/\n1M pop\n      Population          Continent  \
# 0                                                                All
# 1    460,458,760        1,384,132    332,669,677       North America
# 2    307,583,991          221,022  1,391,642,201                Asia
# 3     46,834,128          218,998    213,856,608       South America
# 4     79,617,249        1,217,432     65,397,697              Europe
# ..           ...              ...             ...                ...
# 218        5,318          921,664          5,770       North America
# 219        4,500            6,417        701,257   Australia/Oceania
# 220                                       59,533   Australia/Oceania
# 221                                        6,093              Africa
# 222                                      116,057   Australia/Oceania
#
#     1 Caseevery X ppl 1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop  \
# 0                  \n
# 1                  10                557                 1               13
# 2                  59              5,416                 5              179
# 3                  14                502                 5
# 4                  11                612                 1
# ..                ...                ...               ...              ...
# 218               231                                    1
# 219            35,063                                  156
# 220            14,883
# 221             3,047
# 222           116,057
#
#     New Deaths/1M pop Active Cases/1M pop
# 0
# 1                 0.3              19,234
# 2                   2               2,674
# 3                                   4,733
# 4                                  11,338
# ..                ...                 ...
# 218
# 219
# 220
# 221
# 222
#
# [223 rows x 22 columns]

# %%
from datetime import date
today = date.today()
df.to_csv('%s.csv'% str(today))

# %%
today = date.today()
str(today)
# Out:
# '2021-05-12'
